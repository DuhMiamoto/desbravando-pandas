# %%
import pandas as pd

pd.set_option('display.max_rows', 500)

# %%
df_produto = pd.read_csv('../data/produto.csv')

# %%
df_produto.sort_values(by='vlPreco', ascending=False)
# Out:
#                        descItem  vlPreco
# 43               massa integral    13.75
# 42                 massa grossa    12.00
# 83                  vinho tinto    12.00
# 62                  queijo brie    11.25
# 64                queijo coalho    10.50
# 71                       ricota    10.25
# 35                   gorgonzola     9.50
# 44            massa tradicional     9.25
# 31                 cream cheese     9.00
# 28                      cheddar     8.45
# 22                     catupiry     7.50
# 70                 refrigerante     7.25
# 52                     parmesão     7.00
# 41                  massa final     7.00
# 60                    provolone     7.00
# 27                      cerveja     6.75
# 75              suco de abacaxi     6.50
# 77             suco de maracujá     6.50
# 81                  tomate seco     6.25
# 47                    mussarela     6.00
# 76              suco de laranja     6.00
# 18                      camarão     6.00
# 29                   chá gelado     6.00
# 78                  suco de uva     5.75
# 0                       abacate     5.25
# 84                 água com gás     5.00
# 38                     limonada     5.00
# 69             queijo roquefort     5.00
# 20                   carne seca     5.00
# 73               sabor catupiry     5.00
# 21                    castanhas     4.75
# 8           anchova em conserva     4.50
# 66              queijo de cabra     4.50
# 67                  queijo feta     4.00
# 63               queijo cheddar     4.00
# 9                          atum     4.00
# 7                       anchova     4.00
# 40  linguiça calabresa defumada     4.00
# 65       queijo coalho grelhado     4.00
# 19                  carne moída     4.00
# 26                       cereja     3.80
# 82                    uva passa     3.75
# 39                     linguiça     3.50
# 48                        nozes     3.50
# 68                 queijo gouda     3.50
# 53                    pepperoni     3.50
# 34                       frango     3.50
# 17                    calabresa     3.50
# 6                      amêndoas     3.50
# 3                     alcaparra     3.00
# 51                      palmito     3.00
# 12                        bacon     3.00
# 14                    beterraba     2.50
# 24          cebola caramelizada     2.50
# 61                      pêssego     2.50
# 59                     presunto     2.50
# 1                       abacaxi     2.50
# 33                    espinafre     2.50
# 16                     brócolis     2.50
# 79                         tofu     2.50
# 37                     lentilha     2.50
# 50                          ovo     2.50
# 36                 grão de bico     2.50
# 5                     alho-poró     2.50
# 72                       rúcula     2.00
# 2                     abobrinha     2.00
# 55             pimenta biquinho     2.00
# 10              azeite de oliva     2.00
# 58              pimentão assado     2.00
# 30                    cogumelos     2.00
# 13                    berinjela     2.00
# 45                          mel     2.00
# 11                     azeitona     1.50
# 23                       cebola     1.50
# 32                      ervilha     1.50
# 80                       tomate     1.50
# 46                        milho     1.50
# 54                       picles     1.50
# 56            pimenta calabresa     1.50
# 57                     pimentão     1.50
# 49                      orégano     1.00
# 4                          alho     1.00
# 74                     salsinha     1.00
# 25                    cebolinha     1.00
# 15            borda tradicional     0.00

# %%
df_produto.sort_values(by=['vlPreco', 'descItem'], ascending=[False, True])
# Out:
#                        descItem  vlPreco
# 43               massa integral    13.75
# 42                 massa grossa    12.00
# 83                  vinho tinto    12.00
# 62                  queijo brie    11.25
# 64                queijo coalho    10.50
# 71                       ricota    10.25
# 35                   gorgonzola     9.50
# 44            massa tradicional     9.25
# 31                 cream cheese     9.00
# 28                      cheddar     8.45
# 22                     catupiry     7.50
# 70                 refrigerante     7.25
# 41                  massa final     7.00
# 52                     parmesão     7.00
# 60                    provolone     7.00
# 27                      cerveja     6.75
# 75              suco de abacaxi     6.50
# 77             suco de maracujá     6.50
# 81                  tomate seco     6.25
# 18                      camarão     6.00
# 29                   chá gelado     6.00
# 47                    mussarela     6.00
# 76              suco de laranja     6.00
# 78                  suco de uva     5.75
# 0                       abacate     5.25
# 20                   carne seca     5.00
# 38                     limonada     5.00
# 69             queijo roquefort     5.00
# 73               sabor catupiry     5.00
# 84                 água com gás     5.00
# 21                    castanhas     4.75
# 8           anchova em conserva     4.50
# 66              queijo de cabra     4.50
# 7                       anchova     4.00
# 9                          atum     4.00
# 19                  carne moída     4.00
# 40  linguiça calabresa defumada     4.00
# 63               queijo cheddar     4.00
# 65       queijo coalho grelhado     4.00
# 67                  queijo feta     4.00
# 26                       cereja     3.80
# 82                    uva passa     3.75
# 6                      amêndoas     3.50
# 17                    calabresa     3.50
# 34                       frango     3.50
# 39                     linguiça     3.50
# 48                        nozes     3.50
# 53                    pepperoni     3.50
# 68                 queijo gouda     3.50
# 3                     alcaparra     3.00
# 12                        bacon     3.00
# 51                      palmito     3.00
# 1                       abacaxi     2.50
# 5                     alho-poró     2.50
# 14                    beterraba     2.50
# 16                     brócolis     2.50
# 24          cebola caramelizada     2.50
# 33                    espinafre     2.50
# 36                 grão de bico     2.50
# 37                     lentilha     2.50
# 50                          ovo     2.50
# 59                     presunto     2.50
# 61                      pêssego     2.50
# 79                         tofu     2.50
# 2                     abobrinha     2.00
# 10              azeite de oliva     2.00
# 13                    berinjela     2.00
# 30                    cogumelos     2.00
# 45                          mel     2.00
# 55             pimenta biquinho     2.00
# 58              pimentão assado     2.00
# 72                       rúcula     2.00
# 11                     azeitona     1.50
# 23                       cebola     1.50
# 32                      ervilha     1.50
# 46                        milho     1.50
# 54                       picles     1.50
# 56            pimenta calabresa     1.50
# 57                     pimentão     1.50
# 80                       tomate     1.50
# 4                          alho     1.00
# 25                    cebolinha     1.00
# 49                      orégano     1.00
# 74                     salsinha     1.00
# 15            borda tradicional     0.00
